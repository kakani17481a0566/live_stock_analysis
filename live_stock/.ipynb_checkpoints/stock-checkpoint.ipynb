# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_stock = pd.read_csv('bank_stocks_historical_data.csv')

# %%
line_brack ="================================================================================================================="
colors = ['lightcoral', 'lightblue', 'lightgreen', 'peachpuff', 'lavender', 'mintcream', 'palegoldenrod', 'thistle', 'lightyellow', 'skyblue', 'lightpink', 'honeydew', 'lavenderblush']

# %%
print(df_stock.columns)

print(df_stock.index)

print(df_stock.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# RangeIndex(start=0, stop=12320, step=1)
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# Ticker           object
# dtype: object

# %% [markdown]
# # General Overview

# %% [markdown]
# ### 1. What are the dimensions of the DataFrame?

# %%
df_stock.shape
# Out:
# (12320, 9)

# %% [markdown]
# ### 2. What are the column names?

# %%
df_stock.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')

# %% [markdown]
# ### 3. What are the data types of each column?

# %%
df_stock.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# Ticker           object
# dtype: object

# %% [markdown]
# ### 4. How many missing values are in each column?

# %%
df_stock.isna().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Ticker          0
# dtype: int64

# %% [markdown]
# ### 5. What is the summary statistics of numerical columns?

# %%
df_stock.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  12320.000000  12320.000000  12320.000000  12320.000000  1.232000e+04
# mean     788.068519    796.368645    779.003760    787.776851  1.340514e+07
# std      489.072552    493.409758    484.417498    489.024525  1.521618e+07
# min      142.710864    144.198637    136.496016    139.764587  0.000000e+00
# 25%      402.053072    407.625490    396.850459    401.520096  4.204950e+06
# 50%      665.903604    673.555315    657.028316    665.871185  9.444325e+06
# 75%     1079.973381   1091.015670   1069.928014   1079.848663  1.680871e+07
# max     2194.462122   2247.328709   2171.121122   2205.384521  2.868577e+08
#
#           Dividends  Stock Splits
# count  12320.000000  12320.000000
# mean       0.017335      0.001631
# std        0.402679      0.104364
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       19.500000     10.000000

# %% [markdown]
# ### 6. What are the unique values in the `Ticker` column?

# %%
df_stock['Ticker'].unique()
# Out:
# array(['HDFCBANK.NS', 'ICICIBANK.NS', 'KOTAKBANK.NS', 'SBIN.NS',
#        'AXISBANK.NS'], dtype=object)

# %%
v = df_stock['Ticker'].unique()
print(df_stock['Ticker'].unique())
print(line_brack)


# Print unique tickers
print("Unique Tickers:")
print(df_stock['Ticker'].unique())
print("\n")  # Line break

# Take input from user
stock_name = input(print(f"Please enter a stock ticker: {v}") )
# Out:
# ['HDFCBANK.NS' 'ICICIBANK.NS' 'KOTAKBANK.NS' 'SBIN.NS' 'AXISBANK.NS']
# =================================================================================================================
# Unique Tickers:
# ['HDFCBANK.NS' 'ICICIBANK.NS' 'KOTAKBANK.NS' 'SBIN.NS' 'AXISBANK.NS']
#
#
# Please enter a stock ticker: ['HDFCBANK.NS' 'ICICIBANK.NS' 'KOTAKBANK.NS' 'SBIN.NS' 'AXISBANK.NS']

# %% [markdown]
# ### 7. What is the date range covered in the dataset?

# %%
min_date = df_stock['Date'].min()
max_date = df_stock['Date'].max()

print(f'Date Range ==>  {min_date} to {max_date} ')
# Out:
# Date Range ==>  2014-09-26 00:00:00+05:30 to 2024-09-26 00:00:00+05:30

# %% [markdown]
# ## 8. Are there any duplicate rows in the dataset?

# %%
df_stock.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 9. How can you handle missing values in the dataset?

# %%
df_stock.isna().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Ticker          0
# dtype: int64

# %% [markdown]
# ### 10. Are there any outliers in numerical columns?

# %%
print(df_stock.columns)
print(line_brack)
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Open'])
plt.title("Open")
plt.show()
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# =================================================================================================================

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['High'])
plt.title("High")
plt.show()

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Low'])
plt.title("Low")
plt.show()

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Close'])
plt.title("Close")
plt.show()

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Volume'])
plt.title("Volume")
plt.show()

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Dividends'])
plt.title("Dividends")
plt.show()

# %%
plt.boxplot(df_stock[df_stock['Ticker'] == stock_name] ['Stock Splits'])
plt.title("Stock Splits")
plt.show()

# %% [markdown]
# ### 11. Are the date formats consistent in the `Date` column?

# %%
df_stock.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# Ticker           object
# dtype: object

# %% [markdown]
# ### 12. Should the `Volume` column be transformed (e.g., logarithm)?

# %% [markdown]
# ### 13. Is the `Ticker` column case-sensitive, and should it be standardized?

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# ### 14. How does the stock price change over time?

# %%
print(df_stock.columns)
print(line_brack)
HDFC = df_stock[df_stock['Ticker']== stock_name]
HDFC['Date'] = pd.to_datetime(HDFC['Date'])
HDFC['Date'] = HDFC['Date'].dt.strftime('%Y-%m-%d')
print(HDFC[['Date', 'Date']].head())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# =================================================================================================================
#          Date        Date
# 0  2014-09-26  2014-09-26
# 1  2014-09-29  2014-09-29
# 2  2014-09-30  2014-09-30
# 3  2014-10-01  2014-10-01
# 4  2014-10-07  2014-10-07
# C:\Users\kakan\AppData\Local\Temp\ipykernel_19380\1529059108.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDFC['Date'] = pd.to_datetime(HDFC['Date'])
# C:\Users\kakan\AppData\Local\Temp\ipykernel_19380\1529059108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDFC['Date'] = HDFC['Date'].dt.strftime('%Y-%m-%d')

# %%
HDFC['Date'] = pd.to_datetime(HDFC['Date'])  
HDFC.set_index('Date', inplace=True) 
print(line_brack) 
print(df_stock.columns)
print(line_brack)
# Out:
# =================================================================================================================
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# =================================================================================================================
# C:\Users\kakan\AppData\Local\Temp\ipykernel_19380\4134594684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDFC['Date'] = pd.to_datetime(HDFC['Date'])

# %%
year_sampel = HDFC.resample('YE')['Close'].max().sort_index()
year_sampel
# Out:
# Date
# 2014-12-31     445.731750
# 2015-12-31     519.704102
# 2016-12-31     616.736023
# 2017-12-31     891.263550
# 2018-12-31    1048.146606
# 2019-12-31    1250.276123
# 2020-12-31    1384.097168
# 2021-12-31    1628.132080
# 2022-12-31    1621.264526
# 2023-12-31    1704.918579
# 2024-12-31    1783.449951
# Freq: YE-DEC, Name: Close, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.plot(year_sampel.index,year_sampel.values, marker = 'o')
plt.xlabel("YEAR")
plt.ylabel("MAX_CLOSING_VALUE")
plt.title("yearly_perfomance_hdfc_stock")
plt.show()

# %% [markdown]
# # All stocks

# %%
print(df_stock.columns)
print(line_brack)
all_stocks =df_stock
all_stocks['Date'] = pd.to_datetime(all_stocks['Date'])
all_stocks['Date'] = all_stocks['Date'].dt.strftime('%Y-%m-%d')
print(all_stocks[['Date', 'Date']].head())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# =================================================================================================================
#          Date        Date
# 0  2014-09-26  2014-09-26
# 1  2014-09-29  2014-09-29
# 2  2014-09-30  2014-09-30
# 3  2014-10-01  2014-10-01
# 4  2014-10-07  2014-10-07

# %%
all_stocks['Date'] = pd.to_datetime(all_stocks['Date'])  
all_stocks.set_index('Date', inplace=True)

# %%
print(all_stocks.columns)
print(line_brack)
try_ = all_stocks.groupby('Ticker')
try_
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')
# =================================================================================================================

# %%
temp =all_stocks

gp = temp[['Ticker','Close']].groupby('Ticker').resample('YE').max('Close')

print(type(gp))


gp.reset_index(inplace=True)

gp.set_index('Ticker')

print(gp.columns)
print(line_brack)

plt.figure(figsize=(15,8))
plt.plot(gp['Ticker'], gp['Close'], marker = 'o')
plt.grid()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['Ticker', 'Date', 'Close'], dtype='object')
# =================================================================================================================

# %%
gp
# Out:
#           Ticker       Date        Close
# 0    AXISBANK.NS 2014-12-31   486.245667
# 1    AXISBANK.NS 2015-12-31   626.728455
# 2    AXISBANK.NS 2016-12-31   626.203491
# 3    AXISBANK.NS 2017-12-31   560.807007
# 4    AXISBANK.NS 2018-12-31   656.371460
# 5    AXISBANK.NS 2019-12-31   818.214355
# 6    AXISBANK.NS 2020-12-31   753.666199
# 7    AXISBANK.NS 2021-12-31   841.433777
# 8    AXISBANK.NS 2022-12-31   947.069275
# 9    AXISBANK.NS 2023-12-31  1131.576660
# 10   AXISBANK.NS 2024-12-31  1317.300049
# 11   HDFCBANK.NS 2014-12-31   445.731750
# 12   HDFCBANK.NS 2015-12-31   519.704102
# 13   HDFCBANK.NS 2016-12-31   616.736023
# 14   HDFCBANK.NS 2017-12-31   891.263550
# 15   HDFCBANK.NS 2018-12-31  1048.146606
# 16   HDFCBANK.NS 2019-12-31  1250.276123
# 17   HDFCBANK.NS 2020-12-31  1384.097168
# 18   HDFCBANK.NS 2021-12-31  1628.132080
# 19   HDFCBANK.NS 2022-12-31  1621.264526
# 20   HDFCBANK.NS 2023-12-31  1704.918579
# 21   HDFCBANK.NS 2024-12-31  1783.449951
# 22  ICICIBANK.NS 2014-12-31   299.685852
# 23  ICICIBANK.NS 2015-12-31   317.764648
# 24  ICICIBANK.NS 2016-12-31   251.330048
# 25  ICICIBANK.NS 2017-12-31   309.584778
# 26  ICICIBANK.NS 2018-12-31   355.924927
# 27  ICICIBANK.NS 2019-12-31   531.082275
# 28  ICICIBANK.NS 2020-12-31   530.985596
# 29  ICICIBANK.NS 2021-12-31   816.018921
# 30  ICICIBANK.NS 2022-12-31   929.369995
# 31  ICICIBANK.NS 2023-12-31  1028.545532
# 32  ICICIBANK.NS 2024-12-31  1338.449951
# 33  KOTAKBANK.NS 2014-12-31   650.489136
# 34  KOTAKBANK.NS 2015-12-31   737.304260
# 35  KOTAKBANK.NS 2016-12-31   818.251709
# 36  KOTAKBANK.NS 2017-12-31  1091.453247
# 37  KOTAKBANK.NS 2018-12-31  1403.450806
# 38  KOTAKBANK.NS 2019-12-31  1724.290405
# 39  KOTAKBANK.NS 2020-12-31  2011.871460
# 40  KOTAKBANK.NS 2021-12-31  2205.384521
# 41  KOTAKBANK.NS 2022-12-31  1962.132080
# 42  KOTAKBANK.NS 2023-12-31  2010.489258
# 43  KOTAKBANK.NS 2024-12-31  1934.699951
# 44       SBIN.NS 2014-12-31   292.228790
# 45       SBIN.NS 2015-12-31   304.230743
# 46       SBIN.NS 2016-12-31   262.399017
# 47       SBIN.NS 2017-12-31   317.669983
# 48       SBIN.NS 2018-12-31   310.516479
# 49       SBIN.NS 2019-12-31   350.519409
# 50       SBIN.NS 2020-12-31   319.364197
# 51       SBIN.NS 2021-12-31   503.892731
# 52       SBIN.NS 2022-12-31   603.456909
# 53       SBIN.NS 2023-12-31   644.590454
# 54       SBIN.NS 2024-12-31   905.650024

# %%
year_sampel = df_stock.groupby('Ticker').resample('YE')['Volume'].max().sort_index()
year_sampel = pd.DataFrame(year_sampel)

year_sampel.reset_index(inplace=True)
year_sampel['Ticker'].unique()

year_sampel['diff_Volume'] = 0

# %%
diff_volume = year_sampel[year_sampel['Ticker'] == stock_name]
diff_volume
# Out:
#          Ticker       Date     Volume  diff_Volume
# 11  HDFCBANK.NS 2014-12-31    8332406            0
# 12  HDFCBANK.NS 2015-12-31   17900310            0
# 13  HDFCBANK.NS 2016-12-31   10040196            0
# 14  HDFCBANK.NS 2017-12-31  201129980            0
# 15  HDFCBANK.NS 2018-12-31   44398162            0
# 16  HDFCBANK.NS 2019-12-31   54064350            0
# 17  HDFCBANK.NS 2020-12-31   44318732            0
# 18  HDFCBANK.NS 2021-12-31   21412816            0
# 19  HDFCBANK.NS 2022-12-31   48725485            0
# 20  HDFCBANK.NS 2023-12-31   86705601            0
# 21  HDFCBANK.NS 2024-12-31  222671050            0

# %%
start_trigger = diff_volume.index.min()
end_trigger = diff_volume.index.max()
#print(end_trigger)

for i in (diff_volume.index):
    #print(i)
    if start_trigger  < i  < end_trigger:
      #  print(i)
        k = diff_volume.loc[i]['Volume']-diff_volume.loc[i-1]['Volume']
        #print(k)
        #print(line_brack)
        diff_volume.loc[i, 'diff_Volume'] = k
        
diff_volume
# Out:
#          Ticker       Date     Volume  diff_Volume
# 11  HDFCBANK.NS 2014-12-31    8332406            0
# 12  HDFCBANK.NS 2015-12-31   17900310      9567904
# 13  HDFCBANK.NS 2016-12-31   10040196     -7860114
# 14  HDFCBANK.NS 2017-12-31  201129980    191089784
# 15  HDFCBANK.NS 2018-12-31   44398162   -156731818
# 16  HDFCBANK.NS 2019-12-31   54064350      9666188
# 17  HDFCBANK.NS 2020-12-31   44318732     -9745618
# 18  HDFCBANK.NS 2021-12-31   21412816    -22905916
# 19  HDFCBANK.NS 2022-12-31   48725485     27312669
# 20  HDFCBANK.NS 2023-12-31   86705601     37980116
# 21  HDFCBANK.NS 2024-12-31  222671050            0

# %%
volumne_ =  diff_volume[diff_volume['diff_Volume'] != 0]
volumne_
# Out:
#          Ticker       Date     Volume  diff_Volume
# 12  HDFCBANK.NS 2015-12-31   17900310      9567904
# 13  HDFCBANK.NS 2016-12-31   10040196     -7860114
# 14  HDFCBANK.NS 2017-12-31  201129980    191089784
# 15  HDFCBANK.NS 2018-12-31   44398162   -156731818
# 16  HDFCBANK.NS 2019-12-31   54064350      9666188
# 17  HDFCBANK.NS 2020-12-31   44318732     -9745618
# 18  HDFCBANK.NS 2021-12-31   21412816    -22905916
# 19  HDFCBANK.NS 2022-12-31   48725485     27312669
# 20  HDFCBANK.NS 2023-12-31   86705601     37980116

# %%
volumne_

plt.figure(figsize=(10,5))
plt.plot(volumne_['Date'], volumne_['diff_Volume'],marker = 'o')
plt.grid()

plt.title(stock_name)

plt.xlabel('Date')
plt.ylabel('diff_Volume')

plt.show()

# %% [markdown]
# ### 15. What are the average daily returns for each stock?

# %%
lat_10days_perfomance= HDFC.tail(10)
lat_10days_perfomance.reset_index(inplace=True)

# %%
lat_10days_perfomance['Returen'] = 0
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_19380\792720248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_10days_perfomance['Returen'] = 0

# %%
lat_10days_perfomance
# Out:
#         Date         Open         High          Low        Close    Volume  \
# 0 2024-09-13  1674.000000  1674.000000  1657.050049  1665.949951  11930266
# 1 2024-09-16  1667.000000  1677.800049  1664.050049  1670.949951   7586410
# 2 2024-09-17  1678.000000  1678.000000  1664.150024  1668.800049  10063561
# 3 2024-09-18  1671.849976  1698.900024  1671.099976  1694.800049  20458671
# 4 2024-09-19  1699.199951  1719.000000  1699.150024  1708.500000  15325888
# 5 2024-09-20  1716.500000  1744.949951  1707.550049  1741.199951  30311693
# 6 2024-09-23  1749.000000  1766.349976  1740.250000  1759.800049  13482675
# 7 2024-09-24  1765.000000  1781.650024  1754.250000  1768.050049  16519518
# 8 2024-09-25  1760.150024  1788.000000  1760.150024  1779.099976  15982656
# 9 2024-09-26  1773.050049  1788.000000  1768.050049  1783.449951  15944806
#
#    Dividends  Stock Splits       Ticker  Returen
# 0        0.0           0.0  HDFCBANK.NS        0
# 1        0.0           0.0  HDFCBANK.NS        0
# 2        0.0           0.0  HDFCBANK.NS        0
# 3        0.0           0.0  HDFCBANK.NS        0
# 4        0.0           0.0  HDFCBANK.NS        0
# 5        0.0           0.0  HDFCBANK.NS        0
# 6        0.0           0.0  HDFCBANK.NS        0
# 7        0.0           0.0  HDFCBANK.NS        0
# 8        0.0           0.0  HDFCBANK.NS        0
# 9        0.0           0.0  HDFCBANK.NS        0

# %% [markdown]
# ### 16. How does the trading volume change over time?

# %%
year_sampel
# Out:
#           Ticker       Date     Volume  diff_Volume
# 0    AXISBANK.NS 2014-12-31    7283496            0
# 1    AXISBANK.NS 2015-12-31   33157058            0
# 2    AXISBANK.NS 2016-12-31  120541914            0
# 3    AXISBANK.NS 2017-12-31   49308621            0
# 4    AXISBANK.NS 2018-12-31   58859461            0
# 5    AXISBANK.NS 2019-12-31   55836793            0
# 6    AXISBANK.NS 2020-12-31   96186227            0
# 7    AXISBANK.NS 2021-12-31   64303975            0
# 8    AXISBANK.NS 2022-12-31   58057724            0
# 9    AXISBANK.NS 2023-12-31   36394389            0
# 10   AXISBANK.NS 2024-12-31   46136295            0
# 11   HDFCBANK.NS 2014-12-31    8332406            0
# 12   HDFCBANK.NS 2015-12-31   17900310            0
# 13   HDFCBANK.NS 2016-12-31   10040196            0
# 14   HDFCBANK.NS 2017-12-31  201129980            0
# 15   HDFCBANK.NS 2018-12-31   44398162            0
# 16   HDFCBANK.NS 2019-12-31   54064350            0
# 17   HDFCBANK.NS 2020-12-31   44318732            0
# 18   HDFCBANK.NS 2021-12-31   21412816            0
# 19   HDFCBANK.NS 2022-12-31   48725485            0
# 20   HDFCBANK.NS 2023-12-31   86705601            0
# 21   HDFCBANK.NS 2024-12-31  222671050            0
# 22  ICICIBANK.NS 2014-12-31   26322631            0
# 23  ICICIBANK.NS 2015-12-31   38967790            0
# 24  ICICIBANK.NS 2016-12-31   71191415            0
# 25  ICICIBANK.NS 2017-12-31  128437479            0
# 26  ICICIBANK.NS 2018-12-31   87176185            0
# 27  ICICIBANK.NS 2019-12-31  286857658            0
# 28  ICICIBANK.NS 2020-12-31  125939354            0
# 29  ICICIBANK.NS 2021-12-31   96124084            0
# 30  ICICIBANK.NS 2022-12-31   35959638            0
# 31  ICICIBANK.NS 2023-12-31   41383839            0
# 32  ICICIBANK.NS 2024-12-31   73257767            0
# 33  KOTAKBANK.NS 2014-12-31   12628486            0
# 34  KOTAKBANK.NS 2015-12-31    8026142            0
# 35  KOTAKBANK.NS 2016-12-31   55058370            0
# 36  KOTAKBANK.NS 2017-12-31   10689537            0
# 37  KOTAKBANK.NS 2018-12-31   33807619            0
# 38  KOTAKBANK.NS 2019-12-31   83859904            0
# 39  KOTAKBANK.NS 2020-12-31   78702124            0
# 40  KOTAKBANK.NS 2021-12-31   16268336            0
# 41  KOTAKBANK.NS 2022-12-31   19710178            0
# 42  KOTAKBANK.NS 2023-12-31   88598126            0
# 43  KOTAKBANK.NS 2024-12-31   66179079            0
# 44       SBIN.NS 2014-12-31   50846690            0
# 45       SBIN.NS 2015-12-31   70540056            0
# 46       SBIN.NS 2016-12-31   86616475            0
# 47       SBIN.NS 2017-12-31  262677081            0
# 48       SBIN.NS 2018-12-31  111510771            0
# 49       SBIN.NS 2019-12-31  128449327            0
# 50       SBIN.NS 2020-12-31  201321234            0
# 51       SBIN.NS 2021-12-31  214955688            0
# 52       SBIN.NS 2022-12-31   61403008            0
# 53       SBIN.NS 2023-12-31   52725616            0
# 54       SBIN.NS 2024-12-31  122381193            0

# %%
df_stock.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')

# %%
year_sampel = df_stock.groupby('Ticker').resample('YE')['Volume'].max().sort_index()
year_sampel = pd.DataFrame(year_sampel)

year_sampel.reset_index(inplace=True)
year_sampel['Ticker'].unique()

year_sampel['diff_Volume'] = 0

# %%
#array(['AXISBANK.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'KOTAKBANK.NS',   'SBIN.NS'], dtype=object)

diff_volume = year_sampel[year_sampel['Ticker'] == stock_name]
diff_volume
# Out:
#          Ticker       Date     Volume  diff_Volume
# 11  HDFCBANK.NS 2014-12-31    8332406            0
# 12  HDFCBANK.NS 2015-12-31   17900310            0
# 13  HDFCBANK.NS 2016-12-31   10040196            0
# 14  HDFCBANK.NS 2017-12-31  201129980            0
# 15  HDFCBANK.NS 2018-12-31   44398162            0
# 16  HDFCBANK.NS 2019-12-31   54064350            0
# 17  HDFCBANK.NS 2020-12-31   44318732            0
# 18  HDFCBANK.NS 2021-12-31   21412816            0
# 19  HDFCBANK.NS 2022-12-31   48725485            0
# 20  HDFCBANK.NS 2023-12-31   86705601            0
# 21  HDFCBANK.NS 2024-12-31  222671050            0

# %%
start_trigger = diff_volume.index.min()
end_trigger = diff_volume.index.max()
#print(end_trigger)

for i in (diff_volume.index):
    #print(i)
    if start_trigger  < i  < end_trigger:
      #  print(i)
        k = diff_volume.loc[i]['Volume']-diff_volume.loc[i-1]['Volume']
        #print(k)
        #print(line_brack)
        diff_volume.loc[i, 'diff_Volume'] = k
        
diff_volume
# Out:
#          Ticker       Date     Volume  diff_Volume
# 11  HDFCBANK.NS 2014-12-31    8332406            0
# 12  HDFCBANK.NS 2015-12-31   17900310      9567904
# 13  HDFCBANK.NS 2016-12-31   10040196     -7860114
# 14  HDFCBANK.NS 2017-12-31  201129980    191089784
# 15  HDFCBANK.NS 2018-12-31   44398162   -156731818
# 16  HDFCBANK.NS 2019-12-31   54064350      9666188
# 17  HDFCBANK.NS 2020-12-31   44318732     -9745618
# 18  HDFCBANK.NS 2021-12-31   21412816    -22905916
# 19  HDFCBANK.NS 2022-12-31   48725485     27312669
# 20  HDFCBANK.NS 2023-12-31   86705601     37980116
# 21  HDFCBANK.NS 2024-12-31  222671050            0

# %%
volumne_ =  diff_volume[diff_volume['diff_Volume'] != 0]
volumne_
# Out:
#          Ticker       Date     Volume  diff_Volume
# 12  HDFCBANK.NS 2015-12-31   17900310      9567904
# 13  HDFCBANK.NS 2016-12-31   10040196     -7860114
# 14  HDFCBANK.NS 2017-12-31  201129980    191089784
# 15  HDFCBANK.NS 2018-12-31   44398162   -156731818
# 16  HDFCBANK.NS 2019-12-31   54064350      9666188
# 17  HDFCBANK.NS 2020-12-31   44318732     -9745618
# 18  HDFCBANK.NS 2021-12-31   21412816    -22905916
# 19  HDFCBANK.NS 2022-12-31   48725485     27312669
# 20  HDFCBANK.NS 2023-12-31   86705601     37980116

# %%
volumne_

plt.figure(figsize=(10,5))
plt.plot(volumne_['Date'], volumne_['diff_Volume'],marker = 'o')
plt.grid()

plt.title(stock_name)

plt.xlabel('Date')
plt.ylabel('diff_Volume')

plt.show()

# %% [markdown]
# ### 17. What is the trend in stock prices over different time periods (daily, weekly, monthly)?

# %%
#### 17. What is the trend in stock prices over different time periods (daily, weekly, monthly)?

data_set_17 =   df_stock[df_stock['Ticker'] == stock_name] 

daily_30_days = data_set_17.resample('D').max().tail(30)

daily_30_days =daily_30_days[daily_30_days['Ticker'] != 0 ]
daily_30_days = daily_30_days.dropna()

daily_30_days
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2024-08-28  1637.750000  1639.750000  1630.199951  1637.099976   13460594.0
# 2024-08-29  1642.000000  1644.400024  1631.150024  1638.550049   24526302.0
# 2024-08-30  1656.000000  1662.000000  1621.150024  1636.900024  222671050.0
# 2024-09-02  1646.800049  1646.800049  1623.199951  1626.949951   17024840.0
# 2024-09-03  1634.000000  1639.949951  1624.599976  1637.349976   18641430.0
# 2024-09-04  1639.000000  1644.800049  1632.000000  1641.800049   12341372.0
# 2024-09-05  1646.000000  1649.900024  1642.000000  1645.449951   11438159.0
# 2024-09-06  1638.300049  1647.750000  1634.099976  1636.949951   13014801.0
# 2024-09-09  1638.000000  1648.500000  1630.099976  1646.500000   11896457.0
# 2024-09-10  1654.000000  1654.000000  1638.000000  1650.349976   13303323.0
# 2024-09-11  1650.400024  1652.500000  1639.199951  1643.900024   11113342.0
# 2024-09-12  1654.000000  1670.000000  1647.050049  1666.599976   16212023.0
# 2024-09-13  1674.000000  1674.000000  1657.050049  1665.949951   11930266.0
# 2024-09-16  1667.000000  1677.800049  1664.050049  1670.949951    7586410.0
# 2024-09-17  1678.000000  1678.000000  1664.150024  1668.800049   10063561.0
# 2024-09-18  1671.849976  1698.900024  1671.099976  1694.800049   20458671.0
# 2024-09-19  1699.199951  1719.000000  1699.150024  1708.500000   15325888.0
# 2024-09-20  1716.500000  1744.949951  1707.550049  1741.199951   30311693.0
# 2024-09-23  1749.000000  1766.349976  1740.250000  1759.800049   13482675.0
# 2024-09-24  1765.000000  1781.650024  1754.250000  1768.050049   16519518.0
# 2024-09-25  1760.150024  1788.000000  1760.150024  1779.099976   15982656.0
# 2024-09-26  1773.050049  1788.000000  1768.050049  1783.449951   15944806.0
#
#             Dividends  Stock Splits       Ticker
# Date
# 2024-08-28        0.0           0.0  HDFCBANK.NS
# 2024-08-29        0.0           0.0  HDFCBANK.NS
# 2024-08-30        0.0           0.0  HDFCBANK.NS
# 2024-09-02        0.0           0.0  HDFCBANK.NS
# 2024-09-03        0.0           0.0  HDFCBANK.NS
# 2024-09-04        0.0           0.0  HDFCBANK.NS
# 2024-09-05        0.0           0.0  HDFCBANK.NS
# 2024-09-06        0.0           0.0  HDFCBANK.NS
# 2024-09-09        0.0           0.0  HDFCBANK.NS
# 2024-09-10        0.0           0.0  HDFCBANK.NS
# 2024-09-11        0.0           0.0  HDFCBANK.NS
# 2024-09-12        0.0           0.0  HDFCBANK.NS
# 2024-09-13        0.0           0.0  HDFCBANK.NS
# 2024-09-16        0.0           0.0  HDFCBANK.NS
# 2024-09-17        0.0           0.0  HDFCBANK.NS
# 2024-09-18        0.0           0.0  HDFCBANK.NS
# 2024-09-19        0.0           0.0  HDFCBANK.NS
# 2024-09-20        0.0           0.0  HDFCBANK.NS
# 2024-09-23        0.0           0.0  HDFCBANK.NS
# 2024-09-24        0.0           0.0  HDFCBANK.NS
# 2024-09-25        0.0           0.0  HDFCBANK.NS
# 2024-09-26        0.0           0.0  HDFCBANK.NS

# %%
weekly_1_month = daily_30_days.resample('W').max()
weekly_1_month['Ticker'] = stock_name

weekly_1_month
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2024-09-01  1656.000000  1662.000000  1631.150024  1638.550049  222671050.0
# 2024-09-08  1646.800049  1649.900024  1642.000000  1645.449951   18641430.0
# 2024-09-15  1674.000000  1674.000000  1657.050049  1666.599976   16212023.0
# 2024-09-22  1716.500000  1744.949951  1707.550049  1741.199951   30311693.0
# 2024-09-29  1773.050049  1788.000000  1768.050049  1783.449951   16519518.0
#
#             Dividends  Stock Splits       Ticker
# Date
# 2024-09-01        0.0           0.0  HDFCBANK.NS
# 2024-09-08        0.0           0.0  HDFCBANK.NS
# 2024-09-15        0.0           0.0  HDFCBANK.NS
# 2024-09-22        0.0           0.0  HDFCBANK.NS
# 2024-09-29        0.0           0.0  HDFCBANK.NS

# %%
monthly_1year = data_set_17.resample('ME').max().tail(12)
monthly_1year
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2023-10-31  1534.791783  1534.791783  1514.321315  1528.971191   27780899
# 2023-11-30  1548.011205  1551.266677  1521.374936  1538.145996   34745720
# 2023-12-31  1686.273199  1698.210169  1679.071492  1686.223877   69418565
# 2024-01-31  1683.017598  1686.125187  1669.206199  1676.210571   85072618
# 2024-02-29  1455.129536  1460.900704  1436.434898  1446.596069   45660405
# 2024-03-31  1445.757590  1451.775390  1430.565026  1440.726318   71806902
# 2024-04-30  1536.419530  1536.419530  1520.783118  1528.675293   44467533
# 2024-05-31  1530.099976  1545.000000  1524.800049  1531.550049   37039794
# 2024-06-30  1707.949951  1716.949951  1691.099976  1711.349976   45065598
# 2024-07-31  1791.000000  1794.000000  1764.650024  1768.650024   61608901
# 2024-08-31  1656.000000  1675.949951  1647.349976  1660.099976  222671050
# 2024-09-30  1773.050049  1788.000000  1768.050049  1783.449951   30311693
#
#             Dividends  Stock Splits       Ticker
# Date
# 2023-10-31        0.0           0.0  HDFCBANK.NS
# 2023-11-30        0.0           0.0  HDFCBANK.NS
# 2023-12-31        0.0           0.0  HDFCBANK.NS
# 2024-01-31        0.0           0.0  HDFCBANK.NS
# 2024-02-29        0.0           0.0  HDFCBANK.NS
# 2024-03-31        0.0           0.0  HDFCBANK.NS
# 2024-04-30        0.0           0.0  HDFCBANK.NS
# 2024-05-31       19.5           0.0  HDFCBANK.NS
# 2024-06-30        0.0           0.0  HDFCBANK.NS
# 2024-07-31        0.0           0.0  HDFCBANK.NS
# 2024-08-31        0.0           0.0  HDFCBANK.NS
# 2024-09-30        0.0           0.0  HDFCBANK.NS

# %%
print(monthly_1year.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')

# %%
### 17. What is the trend in stock prices over different time periods (daily, weekly, monthly)?

#monthly_1year
monthly_1year
print(monthly_1year.columns)
print(line_brack)

plt.figure(figsize=(16,8))
plt.plot(monthly_1year.index, monthly_1year['Close'], marker = 'o')
plt.grid()
plt.title(stock_name)
plt.xlabel('monthly_1year')
plt.ylabel('CLOSE')

plt.show()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')
# =================================================================================================================

# %%
weekly_1_month
print(weekly_1_month.columns)
print(line_brack)
print(weekly_1_month.shape)

plt.figure(figsize=(16,8))
plt.plot(weekly_1_month.index, weekly_1_month['Close'], marker = 'o')
plt.grid()
plt.title(stock_name)
plt.xlabel('weekly_1_month')
plt.ylabel('CLOSE _ VALUE')

plt.show()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')
# =================================================================================================================
# (5, 8)

# %%
daily_30_days

print(daily_30_days.columns)
print(line_brack)
print(daily_30_days.shape)

plt.figure(figsize=(16,8))
plt.plot(daily_30_days.index, daily_30_days['Close'], marker = 'o')
plt.grid()
plt.title(stock_name)
plt.xlabel('daily_30_days')
plt.ylabel('CLOSE _ VALUE')

plt.show()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Ticker'],
#       dtype='object')
# =================================================================================================================
# (22, 8)
